# %% [markdown]
# # Introduction & Setup
#
# In this notebook you'll first load and display a dataset in the notebook. Then you'll port that code to a Streamlit app.
#
# ### Exercise #1: Jupyter
#
# The code below loads and displays a dataset. Click the "Play" icon next to the cell below to run it. What can you learn about the dataset from the output?
#
# *Bonus*: Which state had the lowest population?

# %%
import pandas as pd

df = pd.read_csv("state_data.csv")

df

# %% [markdown]
# ### Exercise #2: Streamlit
#
# 1. Open the file `1-intro.py`. This file is a streamlit app. Can you guess what it does?
# 2. Run the app by typing `streamlit run 1-intro.py` in the console. A browser with a blank screen should appear.
# 3. Replace the contents of `1-intro.py` with the code below and save the file.
# 4. After saving the file, the word "Rerun" should appear in the app. Click it.
# 5. The app should update with a table.
#
# *Bonus*: Which state had the lowest population?

# %%
import streamlit as st
import pandas as pd

df = pd.read_csv("state_data.csv")

st.dataframe(df)
